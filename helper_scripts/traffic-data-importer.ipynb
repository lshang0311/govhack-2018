# %%
from elasticsearch import Elasticsearch, RequestsHttpConnection, helpers
from requests_aws4auth import AWS4Auth
import boto3
import csv

# %%
datapath = 'crash_db.csv'
host = 'search-govhack2018-u3oyqcrcukqglza4uqijk7xl5m.ap-southeast-2.es.amazonaws.com'
region = 'ap-southeast-2'
service = 'es'
access_key = ''
secret_key = ''

# %%
# Example of One Entry
# pip install elasticsearch==6.3.1
#credentials = boto3.Session().get_credentials()

awsauth = AWS4Auth(access_key, secret_key, region, service)

es = Elasticsearch(
    hosts = [{'host': host, 'port': 443}],
    http_auth = awsauth,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection
)

# %%
es.indices.delete(index = 'crashes')
# Out:
# DELETE https://search-govhack2018-u3oyqcrcukqglza4uqijk7xl5m.ap-southeast-2.es.amazonaws.com:443/crashes [status:404 request:0.012s]
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-11-a043439afe94> in <module>()
# ----> 1 es.indices.delete(index = 'crashes')
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#      74                 if p in kwargs:
#      75                     params[p] = kwargs.pop(p)
# ---> 76             return func(*args, params=params, **kwargs)
#      77         return _wrapped
#      78     return _wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch/client/indices.py in delete(self, index, params)
#     183             raise ValueError("Empty value passed for a required argument 'index'.")
#     184         return self.transport.perform_request('DELETE', _make_path(index),
# --> 185             params=params)
#     186
#     187     @query_params('allow_no_indices', 'expand_wildcards', 'flat_settings',
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     316                 delay = 2**attempt - 1
#     317                 time.sleep(delay)
# --> 318                 status, headers_response, data = connection.perform_request(method, url, params, body, headers=headers, ignore=ignore, timeout=timeout)
#     319
#     320             except TransportError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch/connection/http_requests.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#      88         if not (200 <= response.status_code < 300) and response.status_code not in ignore:
#      89             self.log_request_fail(method, url, response.request.path_url, body, duration, response.status_code, raw_data)
# ---> 90             self._raise_error(response.status_code, raw_data)
#      91
#      92         self.log_request_success(method, url, response.request.path_url, body, response.status_code, raw_data, duration)
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch/connection/base.py in _raise_error(self, status_code, raw_data)
#     123             logger.warning('Undecodable raw error response from server: %s', err)
#     124
# --> 125         raise HTTP_EXCEPTIONS.get(status_code, TransportError)(status_code, error_message, additional_info)
#     126
#     127
#
# NotFoundError: NotFoundError(404, 'index_not_found_exception', 'no such index')

# %%
mapping = '''
{
"mappings": {
  "crash": {
    "properties": {
      "Long": {
        "type": "text"
      },
      "Lat": {
        "type": "text"
      },
      "Geo": {
        "type": "geo_point"
      }
    }
  }
}
}
'''

es.indices.create(index="crashes", ignore=400, body=mapping)
# Out:
# {'acknowledged': True, 'index': 'crashes', 'shards_acknowledged': True}

# %%
crashes = []
i = 0
with open(datapath, newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader, None)  # skip the headers
    for row in reader:
        i += 1
        
        crash = {
            "id": row[0],
            "Geo": row[28]+","+row[29]
        }
        
        crashes.append(crash)
#         if i == 10:
#             break

# print(crashes)
helpers.bulk(es, crashes, index='crashes', doc_type='crash', refresh = True)
# Out:
# ---------------------------------------------------------------------------
# BulkIndexError                            Traceback (most recent call last)
# <ipython-input-15-1bfdfe44fc65> in <module>()
#      17
#      18 # print(crashes)
# ---> 19 helpers.bulk(es, crashes, index='crashes', doc_type='crash', refresh = True)
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch/helpers/__init__.py in bulk(client, actions, stats_only, *args, **kwargs)
#     255     # make streaming_bulk yield successful results so we can count them
#     256     kwargs['yield_ok'] = True
# --> 257     for ok, item in streaming_bulk(client, actions, *args, **kwargs):
#     258         # go through request-reponse pairs and detect failures
#     259         if not ok:
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch/helpers/__init__.py in streaming_bulk(client, actions, chunk_size, max_chunk_bytes, raise_on_error, expand_action_callback, raise_on_exception, max_retries, initial_backoff, max_backoff, yield_ok, *args, **kwargs)
#     190                             _process_bulk_chunk(client, bulk_actions, bulk_data,
#     191                                                 raise_on_exception,
# --> 192                                                 raise_on_error, *args, **kwargs)
#     193                         ):
#     194
#
# ~/anaconda3/lib/python3.6/site-packages/elasticsearch/helpers/__init__.py in _process_bulk_chunk(client, bulk_actions, bulk_data, raise_on_exception, raise_on_error, *args, **kwargs)
#     135
#     136     if errors:
# --> 137         raise BulkIndexError('%i document(s) failed to index.' % len(errors), errors)
#     138
#     139 def streaming_bulk(client, actions, chunk_size=500, max_chunk_bytes=100 * 1024 * 1024,
#
# BulkIndexError: ('183 document(s) failed to index.', [{'index': {'_index': 'crashes', '_type': 'crash', '_id': 'n1y2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'oFy2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'oVy2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'oly2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'o1y2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'pFy2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'pVy2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'ply2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'p1y2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'qFy2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'qVy2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'qly2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'q1y2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', 'Geo': ','}}}, {'index': {'_index': 'crashes', '_type': 'crash', '_id': 'rFy2rWUBrW80nmKTpNvo', 'status': 400, 'error': {'type': 'mapper_parsing_exception', 'reason': 'failed to parse', 'caused_by': {'type': 'array_index_out_of_bounds_exception', 'reason': '0'}}, 'data': {'id': '', ...

# %%
# Bulk Upload Traffic Data

with open(datapath) as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index='crashes', doc_type='crash', refresh = True)
